# %%
import pandas as pd

# %% [markdown]
# # series= 1-D data

# %%
color=pd.Series(["Red","Blue","Green"])

# %%
color
# Out:
# 0      Red
# 1     Blue
# 2    Green
# dtype: object

# %%
color.head()
# Out:
# 0      Red
# 1     Blue
# 2    Green
# dtype: object

# %% [markdown]
# # Datafarme= 2-D Data

# %%
df=pd.DataFrame({"Colors":color})

# %%
df
# Out:
#   Colors
# 0    Red
# 1   Blue
# 2  Green

# %% [markdown]
# # Importing .CSV File

# %%
car_sales=pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Export csv

# %%
car_sales.to_csv("export-car-sales.csv", index=False)
# index true means exporting data with index value included, and index false is vise versa

# %%
df=pd.read_csv("export-car-sales.csv")

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Describe Data

# %%
car_sales.dtypes
# data.something(), means its a function(has brackets in the end)
# data.something, means its a attribute(doesnt have bracket in the end)
# dtype returns datatype
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# columns returns column names
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# index returns dataframes indes details
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# /data/user/0/ru.iiec.pydroid3/cache/ipykernel_2173/4073448239.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   car_sales.mean()
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## Viewing and Selecting Data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(8)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00

# %%
car_sales.tail(4)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [raw]
# Working With loc and iloc functions

# %%
# creating a series with user define index no
animals=pd.Series(["Cat","Dog","Bird","Panda","Snake"],
                 index=[0,3,9,8,3])

# %%
animals
# Out:
# 0      Cat
# 3      Dog
# 9     Bird
# 8    Panda
# 3    Snake
# dtype: object

# %%
# loc means location and it refers to the index value
animals.loc[3]
# Out:
# 3      Dog
# 3    Snake
# dtype: object

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# iloc refers to position
animals.iloc[3]
# Out:
# 'Panda'

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales.head(4)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %% [raw]
# Selecting a column

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
# This will not work with the colunms which includes space
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
# filtering cars made by toyota
car_sales[car_sales["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
# filtering cars that has covered 100000 kms
car_sales[car_sales["Odometer (KM)"]>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %% [raw]
# Cross tab function

# %%
# Cross tab function is very useful for comparingtwo colunms
pd.crosstab(car_sales["Doors"],car_sales["Make"])
# Out:
# Make   BMW  Honda  Nissan  Toyota
# Doors
# 3        0      0       0       1
# 4        0      3       2       3
# 5        1      0       0       0

# %% [raw]
# Groupby function is used to group and apply a function

# %%
# getting the mean of cars grouped by companies
car_sales.groupby(car_sales["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# %matplotlib inline
car_sales["Odometer (KM)"].plot()
# .plot() function is actually using matplotlib library in the back
# %matplotlib inline is a magic function of jupyter notebook (only use if graph is not being displayed)
# Out:
# <AxesSubplot:>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Doors"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales["Price"]=car_sales["Price"].str.replace('[\$\,]',"").astype(float)
# Out:
# /data/user/0/ru.iiec.pydroid3/cache/ipykernel_2173/2493477512.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"]=car_sales["Price"].str.replace('[\$\,]',"").astype(float)

# %%
car_sales=car_sales.rename(columns={"Price":"Price $"})

# %%
car_sales["Price $"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales["Price $"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price $
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %% [markdown]
# ## Data Manupulation

# %%
# String Manupulation in a column

# %%
car_sales["Make"]=car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price $
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
car_sales_missing=pd.read_csv("9.1 car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.fillna(car_sales_missing.mean(), inplace=True)
# Out:
# /data/user/0/ru.iiec.pydroid3/cache/ipykernel_2173/2226123193.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   car_sales_missing.fillna(car_sales_missing.mean(), inplace=True)

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
# While Droping nan value it is better not to make changes in original DF, but make a copy of it

# %%
car_sales_missing_dropped=car_sales_missing.dropna()

# %%
car_sales_missing_dropped
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    4.0      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing_dropped.to_csv("car_sales_missing_droped.csv", index=False)

# %%
s=pd.Series([5,5,5,5,5])

# %%
car_sales["Seats"]=s

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price $  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    NaN
# 6   honda   Blue          45698      4   7500.0    NaN
# 7   honda   Blue          54738      4   7000.0    NaN
# 8  toyota  White          60000      4   6250.0    NaN
# 9  nissan  White          31600      4   9700.0    NaN

# %%
car_sales.fillna(5, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price $  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    5.0
# 6   honda   Blue          45698      4   7500.0    5.0
# 7   honda   Blue          54738      4   7000.0    5.0
# 8  toyota  White          60000      4   6250.0    5.0
# 9  nissan  White          31600      4   9700.0    5.0

# %%
f=[4.5,6.8,3.2,7.1,5.0,4.4,8.1,7.2,6.9,2.8]

# %%
len(f)
# Out:
# 10

# %%
car_sales["Fuel per 100km"]=f
# appending list value in a df column has a criteria that it has the same no index value as the df no null allowed

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price $  Seats  Fuel per 100km
# 0  toyota  White         150043      4   4000.0    5.0             4.5
# 1   honda    Red          87899      4   5000.0    5.0             6.8
# 2  toyota   Blue          32549      3   7000.0    5.0             3.2
# 3     bmw  Black          11179      5  22000.0    5.0             7.1
# 4  nissan  White         213095      4   3500.0    5.0             5.0
# 5  toyota  Green          99213      4   4500.0    5.0             4.4
# 6   honda   Blue          45698      4   7500.0    5.0             8.1
# 7   honda   Blue          54738      4   7000.0    5.0             7.2
# 8  toyota  White          60000      4   6250.0    5.0             6.9
# 9  nissan  White          31600      4   9700.0    5.0             2.8

# %%
car_sales["Total fuel used (L)"]= (car_sales["Odometer (KM)"]/100)*car_sales["Fuel per 100km"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price $  Seats  Fuel per 100km  \
# 0  toyota  White         150043      4   4000.0    5.0             4.5
# 1   honda    Red          87899      4   5000.0    5.0             6.8
# 2  toyota   Blue          32549      3   7000.0    5.0             3.2
# 3     bmw  Black          11179      5  22000.0    5.0             7.1
# 4  nissan  White         213095      4   3500.0    5.0             5.0
# 5  toyota  Green          99213      4   4500.0    5.0             4.4
# 6   honda   Blue          45698      4   7500.0    5.0             8.1
# 7   honda   Blue          54738      4   7000.0    5.0             7.2
# 8  toyota  White          60000      4   6250.0    5.0             6.9
# 9  nissan  White          31600      4   9700.0    5.0             2.8
#
#    Total fuel used (L)
# 0             6751.935
# 1             5977.132
# 2             1041.568
# 3              793.709
# 4            10654.750
# 5             4365.372
# ...

# %%
car_sales["No. of Wheels"]= 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price $  Seats  Fuel per 100km  \
# 0  toyota  White         150043      4   4000.0    5.0             4.5
# 1   honda    Red          87899      4   5000.0    5.0             6.8
# 2  toyota   Blue          32549      3   7000.0    5.0             3.2
# 3     bmw  Black          11179      5  22000.0    5.0             7.1
# 4  nissan  White         213095      4   3500.0    5.0             5.0
# 5  toyota  Green          99213      4   4500.0    5.0             4.4
# 6   honda   Blue          45698      4   7500.0    5.0             8.1
# 7   honda   Blue          54738      4   7000.0    5.0             7.2
# 8  toyota  White          60000      4   6250.0    5.0             6.9
# 9  nissan  White          31600      4   9700.0    5.0             2.8
#
#    Total fuel used (L)  No. of Wheels
# 0             6751.935              4
# 1             5977.132              4
# 2             1041.568              4
# ...

# %%
car_sales["Road saftey"]=True

# %%
car_sales.drop("Total fuel used (L)", axis=1)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price $  Seats  Fuel per 100km  \
# 0  toyota  White         150043      4   4000.0    5.0             4.5
# 1   honda    Red          87899      4   5000.0    5.0             6.8
# 2  toyota   Blue          32549      3   7000.0    5.0             3.2
# 3     bmw  Black          11179      5  22000.0    5.0             7.1
# 4  nissan  White         213095      4   3500.0    5.0             5.0
# 5  toyota  Green          99213      4   4500.0    5.0             4.4
# 6   honda   Blue          45698      4   7500.0    5.0             8.1
# 7   honda   Blue          54738      4   7000.0    5.0             7.2
# 8  toyota  White          60000      4   6250.0    5.0             6.9
# 9  nissan  White          31600      4   9700.0    5.0             2.8
#
#    No. of Wheels  Road saftey
# 0              4         True
# 1              4         True
# 2              4         True
# 3              4         True
# 4              4         True
# ...

# %%
# .sample(frac=value) it collects a shuffled sample from the df frac attribute is the
car_sales_shuffled= car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price $  Seats  Fuel per 100km  \
# 0  toyota  White         150043      4   4000.0    5.0             4.5
# 5  toyota  Green          99213      4   4500.0    5.0             4.4
# 2  toyota   Blue          32549      3   7000.0    5.0             3.2
# 7   honda   Blue          54738      4   7000.0    5.0             7.2
# 8  toyota  White          60000      4   6250.0    5.0             6.9
# 9  nissan  White          31600      4   9700.0    5.0             2.8
# 3     bmw  Black          11179      5  22000.0    5.0             7.1
# 1   honda    Red          87899      4   5000.0    5.0             6.8
# 4  nissan  White         213095      4   3500.0    5.0             5.0
# 6   honda   Blue          45698      4   7500.0    5.0             8.1
#
#    Total fuel used (L)  No. of Wheels  Road saftey
# 0             6751.935              4         True
# 5             4365.372              4         True
# ...

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)
# .reset_index function reset index value and drop attribute drops the old index colunm like index=False in to_csv
# inplace=True means the changes will not only be displayed but will actually be made

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price $  Seats  Fuel per 100km  \
# 0  toyota  White         150043      4   4000.0    5.0             4.5
# 1  toyota  Green          99213      4   4500.0    5.0             4.4
# 2  toyota   Blue          32549      3   7000.0    5.0             3.2
# 3   honda   Blue          54738      4   7000.0    5.0             7.2
# 4  toyota  White          60000      4   6250.0    5.0             6.9
# 5  nissan  White          31600      4   9700.0    5.0             2.8
# 6     bmw  Black          11179      5  22000.0    5.0             7.1
# 7   honda    Red          87899      4   5000.0    5.0             6.8
# 8  nissan  White         213095      4   3500.0    5.0             5.0
# 9   honda   Blue          45698      4   7500.0    5.0             8.1
#
#    Total fuel used (L)  No. of Wheels  Road saftey
# 0             6751.935              4         True
# 1             4365.372              4         True
# ...

# %%
car_sales["Odometer (KM)"]=car_sales["Odometer (KM)"].apply(lambda x: x/1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price $  Seats  Fuel per 100km  \
# 0  toyota  White      93776.875      4   4000.0    5.0             4.5
# 1   honda    Red      54936.875      4   5000.0    5.0             6.8
# 2  toyota   Blue      20343.125      3   7000.0    5.0             3.2
# 3     bmw  Black       6986.875      5  22000.0    5.0             7.1
# 4  nissan  White     133184.375      4   3500.0    5.0             5.0
# 5  toyota  Green      62008.125      4   4500.0    5.0             4.4
# 6   honda   Blue      28561.250      4   7500.0    5.0             8.1
# 7   honda   Blue      34211.250      4   7000.0    5.0             7.2
# 8  toyota  White      37500.000      4   6250.0    5.0             6.9
# 9  nissan  White      19750.000      4   9700.0    5.0             2.8
#
#    Total fuel used (L)  No. of Wheels  Road saftey
# 0             6751.935              4         True
# 1             5977.132              4         True
# ...

# %%
car_sales.rename(columns={"Odometer (KM)" : "Odometer (Miles)"})
# Out:
#      Make Colour  Odometer (Miles)  Doors  Price $  Seats  Fuel per 100km  \
# 0  toyota  White         93776.875      4   4000.0    5.0             4.5
# 1   honda    Red         54936.875      4   5000.0    5.0             6.8
# 2  toyota   Blue         20343.125      3   7000.0    5.0             3.2
# 3     bmw  Black          6986.875      5  22000.0    5.0             7.1
# 4  nissan  White        133184.375      4   3500.0    5.0             5.0
# 5  toyota  Green         62008.125      4   4500.0    5.0             4.4
# 6   honda   Blue         28561.250      4   7500.0    5.0             8.1
# 7   honda   Blue         34211.250      4   7000.0    5.0             7.2
# 8  toyota  White         37500.000      4   6250.0    5.0             6.9
# 9  nissan  White         19750.000      4   9700.0    5.0             2.8
#
#    Total fuel used (L)  No. of Wheels  Road saftey
# 0             6751.935              4         True
# 1             5977.132              4         True
# ...

# %%
car_sales.dtypes
# Out:
# Make                    object
# Colour                  object
# Odometer (KM)          float64
# Doors                    int64
# Price $                float64
# Seats                  float64
# Fuel per 100km         float64
# Total fuel used (L)    float64
# No. of Wheels            int64
# Road saftey               bool
# dtype: object

# %%
# Out:
# kjnvkjbzvkbv
#  vksbcvhbv
